# %% [markdown]
# # 77_Tableau_Actions_Highlight..,
# >>> ### Highlighting will be done on some triggering event..,

# %% [markdown]
# > ### Step-I) Setting up Environment :
# > ### Source Worksheet Default Preview :
# > ![image.png](attachment:image.png)
# > ### Target Worksheet Default Preview :
# > ![image-2.png](attachment:image-2.png)
#
# > ### Step-II) Worksheet-> Actions-> Highlight Option : Explore :
# > ![image-3.png](attachment:image-3.png)
#
# > ### Step-III) Source Worksheet Selection :
# > ![image-4.png](attachment:image-4.png)
# > ## Target Output : (Auto generated)
# > ![image-5.png](attachment:image-5.png)
#
# > ### Step-IV) Create Dashboard & Explore Dashboard Actions Option :
# > ![image-6.png](attachment:image-6.png)
