# %% [markdown]
# # 53_Tableau_Logical_Functions..,
# >> ### If....Else Condition..???

# %% [markdown]
# ## 1) Profit : Graph :
# > ### Step-I) Create Defaulf Graph :
# > ![image.png](attachment:image.png)
#
# > ### Step-II) Create Field : Profit_Status :
# > ![image-2.png](attachment:image-2.png)
#
# > ### Step-III) Profit_Status : Output :
# > ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ## 2) Cross Tab :
# > ## Cross Tab : Profit_Status Output :
# > ![image.png](attachment:image.png)
# > ## OR
# > ![image-2.png](attachment:image-2.png)
