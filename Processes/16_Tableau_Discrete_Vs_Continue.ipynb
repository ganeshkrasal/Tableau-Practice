# %% [markdown]
# # 16_Tableau_Discrete_Vs_Continue..,

# %% [markdown]
# >> ### How to work with Dimensions & Measures..?
# >> ### And what are Discrete & Continuous parts..?

# %% [markdown]
# ## 1) Dimensions & Measures :
# > ![image.png](attachment:image.png)

# %% [markdown]
# ## 2) Discrete & Continuous : (Discrete)
# > ![image.png](attachment:image.png)
# ## Continuous :
# > ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## 3) Coloe Bart Chart :
# > ### a) Without Any Settings :
# > ![image.png](attachment:image.png)
#
# > ### b) When applying Discrete Function :
# > ![image-2.png](attachment:image-2.png)
#
# > ### c) When applying Continuous Function :
# > ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ## 4) Color Map by Measures/Continuous :
# ### (Just By Double Click on 'State')
# > ![image.png](attachment:image.png)
#
# > ### Color Map by Measures/Continuous :
# > ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## 5) Color Map by Discrete/Dimensions :
# > ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## 6) Filters with Discrete & Continuous :
# ### Plot The Graph :
# > ![image.png](attachment:image.png)
# >> ### a) Discrete Filters :
# > ![image-2.png](attachment:image-2.png)
# >> ### b) ontinuous Filters :
# >> ![image-3.png](attachment:image-3.png)

# %% [markdown]
# >>> ## Discrete Filter gives exact value where as Continuous Filter gives Range of values..,
