# %% [markdown]
# # 57_Tableau_Line_Charts..,

# %% [markdown]
# ## 1) Line Chart :
# > ### Default Preview :
# > ![image.png](attachment:image.png)
#
# > ### Line Chart Looks :
# > ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## 2) Date Line Chart :
# > ### Interactive Line Chart : (Explore Option)
# > ![image.png](attachment:image.png)

# %% [markdown]
# ## 3) Discrete Vs Continuous :
# > ### Basics :
# > ![image.png](attachment:image.png)
#
# > ### Change Order Date from Discrete to Continuous :
# > ![image-2.png](attachment:image-2.png)
#
# > ### Both the Fields are Continuous :
# > ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ## Discrete Graph View :
# > ![image.png](attachment:image.png)
# ## Continuous Graph View :
# > ![image-2.png](attachment:image-2.png)
