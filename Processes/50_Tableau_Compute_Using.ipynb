# %% [markdown]
# # 50_Tableau_Compute_Using..,

# %% [markdown]
# ## 1) Bar Graph :
# > ### Step-I) Default View for Compute Using (Explore) :
# > ![image.png](attachment:image.png)
#
# > ### Step-II) Select Compute Using Option :
# > ![image-2.png](attachment:image-2.png)
#
# > ### Step-III) Compute Using Sub-Category : Output :
# > ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ## 2) Cross-Tab:
# > ### Step-I) Default Preview : Cross-Tab :
# > ![image.png](attachment:image.png)
#
# > ### Step-II) Select Percentage of Totals Option 1st : (Observe for Compute Using)
# > ![image-2.png](attachment:image-2.png)
#
# > ### Step-III) Observe Percentage of Total Output :
# > ![image-3.png](attachment:image-3.png)
#
# > ### Step-IV) Compute Using : Table down Or Sub-Category : Output :
# > ![image-4.png](attachment:image-4.png)
#
# > ### Step-V) Compute Using : Table across Or Order Date : Output :
# > ![image-5.png](attachment:image-5.png)
#
# > ### Step-VI) Compute Using : Table : Output (Explore The Option)
# < ![image-6.png](attachment:image-6.png)
