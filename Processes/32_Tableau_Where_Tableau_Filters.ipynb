# %% [markdown]
# # 32_Tableau_Where_Tableau_Filters..,
# >> ### Summary Level Filters & Record Level Filters..??

# %% [markdown]
# ## 1) Summary Level : (Sum of Profits which is Positive)
# > ### If we wants to see only those Categories & Sub-Categories where Profit is greater than zero (i.e. Positive Profit..,)
# > ### Step-I) Grapgh Preview :
# > ![image.png](attachment:image.png)
#
# > ### Step-II) Apply Filters to show Sum of Positive Profits Only :
# > ![image-2.png](attachment:image-2.png)
#
# > ### Step-III) Sum of Positive Profit Output :
# > ![image-4.png](attachment:image-4.png)

# %% [markdown]
# ## 2) Record Level Filter : (All the Positive Profits)
# > ### Step-I) Graph Preview (Aim is to show all the Positive Values) :
# > ![image.png](attachment:image.png)
#
# > ### Step-II) Apply Filters to show All the Positive Profits :
# > ![image-2.png](attachment:image-2.png)
#
# > ### Step-III) All The Positive Profits :
# > ![image-3.png](attachment:image-3.png)
# > ## AND
# > ![image-4.png](attachment:image-4.png)
