# %% [markdown]
# # 38_Tableau_Mark_Text_Label..,
# >> ###

# %% [markdown]
# ## 1) Bar Graph :
# > ### Bar Graph : Mark-Text/Label Profit Output :
# > ![image.png](attachment:image.png)

# %% [markdown]
# ## 2) Line Chart :
# > ### Step-I) Explore Label/Text Edit Options :
# > ![image.png](attachment:image.png)
#
# > ### Step-II) Label/Text Edit Output :
# > ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## 3) Map :
# > ### Map : Mark-Text/Label Sales & Profit Output :
# > ![image.png](attachment:image.png)
