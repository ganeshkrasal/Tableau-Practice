# %% [markdown]
# # 15_Measure_Name_Usage..,

# %% [markdown]
# >> ### Aim is to combine multpile grapghs in one scale..,

# %% [markdown]
# ### Dual Axis :
# > ![image.png](attachment:image.png)
# ### OutPut :
# > ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### So now, to combine all the Graphs in one scale, Measure Names & Values comes into picture :

# %% [markdown]
# > ### Step-I): Output is not what expected, so need to focus on 'Color' Marks :
# ![image-2.png](attachment:image-2.png)
# > ### Step-II) : Expected Output :
# ![image-3.png](attachment:image-3.png)
