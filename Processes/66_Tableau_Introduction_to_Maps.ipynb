# %% [markdown]
# # 66_Tableau_Introduction_to_Maps..,

# %% [markdown]
# ## 1) State Vs Sales : Representation Without Map :
# > ![image.png](attachment:image.png)

# %% [markdown]
# ## 2) State wise Sales :
# > ![image.png](attachment:image.png)

# %% [markdown]
# ## 3) State wise Profit :
# > ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## 4) Symbol Map with Shapes :
# > ![image.png](attachment:image.png)
