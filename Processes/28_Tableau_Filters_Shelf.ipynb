# %% [markdown]
# # 28_Tableau_Filters_Shelf..,
# >> ### How to work with Filters in Tableau..??
# > 1. General Tab.,
# 2. Wildcard Tab.,
# 3. Condotion Tab.,
# 4. Top Tab..,

# %% [markdown]
# ## 1) General Tab :
# > ### Graph Preview :
# > ![image.png](attachment:image.png)
#
# > ### Step-I) Aplly Filters Here :
# > ![image-2.png](attachment:image-2.png)
#
# > ### Step-II) Output :
# > ![image-3.png](attachment:image-3.png)
#
# > ### Step-III) Edit Filters with Exclude Option :
# > ![image-4.png](attachment:image-4.png)
#
# > ### Step-IV) Output with Exclude Option :
# > ![image-5.png](attachment:image-5.png)

# %% [markdown]
# ## 2) Wildcard Tab :
# > ### Graph Preview :
# > ![image.png](attachment:image.png)
#
# > ### Step-I) Create Filter : Start with 'S' Filter :
# > ![image-2.png](attachment:image-2.png)
#
# > ### Step-II) Output of prevous step :
# > ![image-3.png](attachment:image-3.png)
#
# > ### Step-III) Create Filter : Ends with 's' :
# > ![image-4.png](attachment:image-4.png)
#
# > ### Step-IV) Output of prevous step :
# > ![image-5.png](attachment:image-5.png)
#
# > ### Step-V) Exclude Option :
# > ![image-6.png](attachment:image-6.png)
#
# > ### Step-VI) Output of prevous step :
# > ![image-7.png](attachment:image-7.png)

# %% [markdown]
# ## 3) Condition Tab :
# > ### Graph Preview :
# > ![image-2.png](attachment:image-2.png)
#
# > ### Step-I) Create Condition tab Filter :
# > ![image-3.png](attachment:image-3.png)
#
# > ### Step-II) Output with Conditon Filter - Part 1 :
# > ![image-4.png](attachment:image-4.png)
#
#
# > ### Step-III) Output with Conditon Filter - Part 2 :
# > ![image-5.png](attachment:image-5.png)

# %% [markdown]
# ## 4) Top (& Bottom) Tab :
# > ### Graph Preview :
# > ![image.png](attachment:image.png)
#
# > ### Step-I) Show Top 10 Filter :
# > ![image-2.png](attachment:image-2.png)
#
# > ### Step-II) Output with Top 10 Filter :
# > ![image-3.png](attachment:image-3.png)
#
# > ### Step-III) Show Bottom 5 Filter :
# > ![image-4.png](attachment:image-4.png)
#
# > ### Step-IV) Output with Bottom 5 Filter :
# > ![image-5.png](attachment:image-5.png)
