# %% [markdown]
# # 19_Tableau_Sets..,

# %% [markdown]
# >> ### How to work with different types of sets..??
#
# **Sets are basically custom fields, are nothing but subset of data which is created based on some conditions itself..,**

# %% [markdown]
# ## 1) Bar Chart :
#
# > ### Plot the Graph / Bar Chart :
# > ![image.png](attachment:image.png)
#
# > ### Create Set :
# > ![image-2.png](attachment:image-2.png)
#
# > ### Set Created :
# > ![image-3.png](attachment:image-3.png)
#
# > ### Check for Set usage : Color Mark.,
# > ![image-4.png](attachment:image-4.png)
