# %% [markdown]
# # 11_Tableau_Drill_Down_&_Hirearchies..,

# %% [markdown]
# > ### How to create *Drill Down* & *Hirearchy* Otion (Button)..?

# %% [markdown]
# ### 01_ Check For Sales Vs Category Chart Calculations :
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 02_ One can add Sub-Category Option by Drag & Drop :
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 03_ Hirearchy : Combine Category & Sub-Category :
#
# ![image.png](attachment:image.png)
#
# >> ### See The Difference :
#
# ![image-2.png](attachment:image-2.png)
#
# >>> ## &
#
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ## AutoGenerated Hirearchy :
# ### 01_Check for Order Date :
#
# ![image.png](attachment:image.png)
#
# >> ### This is how it looks :
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### 02_ Descrite DatE Fields :
#
# ![image.png](attachment:image.png)
#
# >> ### Output looks alike :
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### 03_Continuous DatE Fields :
#
# ![image.png](attachment:image.png)
#
# >> ### Output looks alike :
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## REMOVE HIREARCHY :
#
# > ![image.png](attachment:image.png)
