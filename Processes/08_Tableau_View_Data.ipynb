# %% [markdown]
# # 08_Tableau_View_Data :

# %% [markdown]
# > ### *How to view your Data from Data Source..??*

# %% [markdown]
# ### View Data 1 :
# - View Data Symbol..,
# - Dialogue Box after clicking View Data..,
# - Toggle for specific no. of Rows.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### View Data 2 - Drag Option :
#
# ![image.png](attachment:image.png)
