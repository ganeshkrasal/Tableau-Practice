# %% [markdown]
# # 55_Tableau_Scatter_Charts..,
# >> ## Different Points are Scattered on Cartition Plane :

# %% [markdown]
# ## 1) Scatter Chart Basics :
# > ### Step-I) Default Preview : Scatter Chart :
# > ![image.png](attachment:image.png)
#
# > ### Step-II) Additional Marks : Color, Text & Shape :
# > ![image-2.png](attachment:image-2.png)
#
# > ### Step-III) Scatter Chart : Customer Name :
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ## 2) Interactive Scatter Chart :
# > ### ![image.png](attachment:image.png)

# %% [markdown]
# ## 3) Scatter Chart : Drop Lines :
# > ### Explore the Option :
# > ![image.png](attachment:image.png)
#
# > ### Drop Line : Output :
# > ![image-3.png](attachment:image-3.png)
#
# > ### Explore Drop Line Edit Option :
# > ![image-4.png](attachment:image-4.png)
