# %% [markdown]
# # 27_Tableau_Data_Blending_Calculations..,
# >> ### How do we create Calculated Field using Data Blending..??

# %% [markdown]
# ## Basic Data Blending :
# > ### Preview :
# > ![image.png](attachment:image.png)

# %% [markdown]
# > ### Step-I) Create Field :
# > ![image.png](attachment:image.png)
#
# > ### Step-II) Calculatoin Window :
# > ![image-2.png](attachment:image-2.png)
#
# > ### Step-III) Direct Output of Previous Step :
# > ![image-3.png](attachment:image-3.png)
#
# > ### Step-IV) Editing the Calculation Window with ZN Function :
# > ![image-4.png](attachment:image-4.png)
#
# > ### Step-V) Final Graph with actual Calculations :
# > ![image-5.png](attachment:image-5.png)
