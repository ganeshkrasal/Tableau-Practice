# %% [markdown]
# # 62_Tableau_Bump_Chart..,
# >> ### *Its a Line Chart where the Rank changes based on the Time.,*

# %% [markdown]
# > ### Step-I) Prepare Line Chart :
# > ![image.png](attachment:image.png)
#
# > ### Step-II) Select Rank Option :
# > ![image-2.png](attachment:image-2.png)
#
# > ### Step-III) Rank of Sales : Output :
# > ![image-3.png](attachment:image-3.png)
#
# > ### Step-IV) Compute Using -> Market : Option Select :
# > ![image-4.png](attachment:image-4.png)
#
# > ### Step-V) Compute Using -> Market : Output
# > ![image-5.png](attachment:image-5.png)
#
# > ### Step-VI) Make Sales Field as Discrete :
# > ![image-7.png](attachment:image-7.png)
#
# > ### Step-VII) Convert to Line Chart & See the Final Bump Chart Output :
# > ![image-8.png](attachment:image-8.png)
