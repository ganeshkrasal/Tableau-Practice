# %% [markdown]
# # 65_Tableau_Pie_Chart..,

# %% [markdown]
# ## 1) Pie Chart Method_01 :
# > ![image.png](attachment:image.png)

# %% [markdown]
# ## 2) Pie Chart Method_02 :
# > ### Step-I) Create Default View : Sales Only Pie Chart :
# > ![image.png](attachment:image.png)
#
# > ### Step-II) Apply Market Field to Marks : Pie Chart Method_02 : Output
# > ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## 3) Pie Chart Method_03 : Explore The Option :
# > ![image.png](attachment:image.png)
