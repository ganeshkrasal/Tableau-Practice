# %% [markdown]
# # 75_Tableau_Highlighting..,
# >> ### Highlighting in Charts, any diagram..??

# %% [markdown]
# ## 1) Highlighting :
# > ### Step-I) Graph Preview : Bar Chart with Multiple Row & Column Fields :
# > ![image-3.png](attachment:image-3.png)
#
# > ### Step-II) Observe Selecting 1 Bar from the Chart :
# > ![image-2.png](attachment:image-2.png)
#
# > ### Step-III) Explore the option : Enable Sheet Highlighting :
# > ![image-4.png](attachment:image-4.png)
#
# > ### Step-IV) Output_01) All Fields Option :
# > ![image-5.png](attachment:image-5.png)
#
# > ### Step-V) Output_02) Date and Time Option :
# > ![image-6.png](attachment:image-6.png)
#
# > ### Step-VI) Output_03) Specific Column Field :
# > ![image-7.png](attachment:image-7.png)
#
# > ### Step-VII) Output_04) Specific Row Field :
# > ![image-8.png](attachment:image-8.png)
#
# > ### Step-VIII) Output_05) Combination of Row & Column Fields :
# > ![image-9.png](attachment:image-9.png)
#
# > ## Explore the Highlight Option Outputs :
# > ![image-10.png](attachment:image-10.png)

# %% [markdown]
# ## 2) Date and Time Option :
# > ### Step-I) Environment :
# > ![image-2.png](attachment:image-2.png)
#
# > ### Step-II) Output : All Fields :
# > ![image-3.png](attachment:image-3.png)
#
# > ### Step-III) Output : Quarter :
# > ![image-4.png](attachment:image-4.png)
#
# > ### Step-IV) Output : YEAR :
# > ![image-5.png](attachment:image-5.png)

# %% [markdown]
# ## Explore Various Optons :
