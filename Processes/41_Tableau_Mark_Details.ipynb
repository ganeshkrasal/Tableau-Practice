# %% [markdown]
# # 41_Tableau_Mark_Details..,
# >> ###

# %% [markdown]
# > ### Step-I) Bar Grapgh Preview without Details Option :
# > ![image.png](attachment:image.png)
#
# > ### Step-II) Bar Graph with Details Option (Market) :
# > ![image-2.png](attachment:image-2.png)
