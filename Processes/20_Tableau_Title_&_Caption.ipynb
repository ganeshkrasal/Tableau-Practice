# %% [markdown]
# # 20_Tableau_Title_&_Caption..,
# >> ### How to insert a Title & a Caption..??  How to format a Title & a Caption..??

# %% [markdown]
# ## 1) Edit the Title & Caption :
# ## Title :
# > ### Plot the Grapgh & See Default View :
# > ![image.png](attachment:image.png)
#
# > ### Edited Title :
# > ![image-2.png](attachment:image-2.png)
#
# ## Caption :
# > ### Check for Caption Option if nos visible default :
# > ![image-3.png](attachment:image-3.png)
#
# > ### Edited Caption :
# > ![image-4.png](attachment:image-4.png)

# %% [markdown]
# ## 2) Format the Title & Caption :
# > ### See the editing Option :
# > ![image.png](attachment:image.png)
#
# > ### Formatted Title & Caption :
# > ![image-2.png](attachment:image-2.png)
