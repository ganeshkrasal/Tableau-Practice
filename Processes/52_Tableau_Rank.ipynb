# %% [markdown]
# # 52_Tableau_Rank..,
# >> ### Rank related functions.., Deals with Number related Measures..,

# %% [markdown]
# ## 1) Rank :
# > ### Step-I) Copy Excel Data & Paste it to Tableau Worksheet :
# > ![image.png](attachment:image.png)
#
# > ### Step-II) Create Rank Calculated Field :
# > ![image-2.png](attachment:image-2.png)
#
# > ### Step-III) RANK : Output : (Convert Rank to Discrete)
# > ![image-4.png](attachment:image-4.png)
#
# > ### Step-IV) Create Field : Rank_Dense :
# > ![image-5.png](attachment:image-5.png)
#
# > ### Step-V) Rank_Dense Output : (Observe the difference)
# > ![image-6.png](attachment:image-6.png)
#
# > ### Step-VI) Create Field : Rank_Modified :
# > ![image-8.png](attachment:image-8.png)
#
# > ### Step-VII) Rank_Modified : Output :
# > ![image-9.png](attachment:image-9.png)
#
# > ### Step-VIII) Create Field : Rank_Unique
# > ![image-10.png](attachment:image-10.png)
#
# > ### Step-IX) Rank Unique : Output :
# > ![image-11.png](attachment:image-11.png)
