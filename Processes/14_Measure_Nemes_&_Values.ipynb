# %% [markdown]
# # 14_Measure_Nemes_&_Values..,

# %% [markdown]
# ### Auto Generated Fields :
# > 1. Measure Names,
# 2. Latitude (generated),
# 3. Longitude (generated),
# 4. Orders (Count),
# 5. Measure Values.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# > ### To see total no. of records :
# ![image.png](attachment:image.png)

# %% [markdown]
# > ### To verify the total count :
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# > ## Measure Names & Vaslues :
# ![image.png](attachment:image.png)

# %% [markdown]
# > ## To see Graphical Representation :
#
#
# ![image.png](attachment:image.png)
