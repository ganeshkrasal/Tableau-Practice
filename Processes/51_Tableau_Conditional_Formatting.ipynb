# %% [markdown]
# # 51_Tableau_Conditional_Formatting..,

# %% [markdown]
# ## 1) INDEX & TopN :
# > ### Step-I) Create Calculated Field : Index
# > ![image.png](attachment:image.png)
#
# > ### Step-II) DragDrop Index to Worksheet & Observe :
# > ![image-2.png](attachment:image-2.png)
#
# > ### Step-III) Convert INDEX to Discrete & see the Output :
# > ![image-3.png](attachment:image-3.png)
#
# > ## Highlighting Top 10 Items :
# > ### Step-IV) Create Calculated Field TopN :
# > ![image-4.png](attachment:image-4.png)
#
# > ### Step-V) Apply Calculation Field TopN & See the Output :
# > ![image-5.png](attachment:image-5.png)
#
# > ## Highlighting Bottom 5 Items :
# > ### Step-VI) Create Calculated Field BottomN :
# > ![image-6.png](attachment:image-6.png)
#
# > ### Step-VII) Apply Calculation Field BottomN & See the Output :
# > ![image-7.png](attachment:image-7.png)

# %% [markdown]
# ## 2) LAST & BottomN :
# > ### Step-I) Create Last Field :
# > ![image.png](attachment:image.png)
#
# > ### Step-II) Make Last as Discrete Field :
# > ![image-2.png](attachment:image-2.png)
#
# > ### Step-III) Apply Last Field on Worksheet & See Output :
# > ![image-3.png](attachment:image-3.png)
#
# > ## Highlighting Bottom 5 Items using LAST :
# > ### Step-IV) Create BottomN_Last Field :
# > ![image-4.png](attachment:image-4.png)
#
# > ### Step-V) Apply Calculation Field BottomN_Last & See the Output :
# > ![image-5.png](attachment:image-5.png)

# %% [markdown]
# ## 3) Top & Bottom :
# > ### Step-I) Create Special Field :
# > ![image.png](attachment:image.png)
#
# > ### Step-II) The Output showing Top 5 & Bottom 5 Values :
# > ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## Show Header Option :
# > ### The Option :
# > ![image.png](attachment:image.png)
#
# > ### The Output :
# > ![image-2.png](attachment:image-2.png)
