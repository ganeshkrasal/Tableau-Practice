# %% [markdown]
# # 39_Tableau_Mark_Tooltip..,
# >> ###

# %% [markdown]
# ## 1) Bar Graph :
# > ### Bar Graph : Tooltip Output :
# > ![image.png](attachment:image.png)

# %% [markdown]
# ## 2) Line Chart :
# > ### Line Chart : Tooltip Output :
# > ![image.png](attachment:image.png)
#
# > ## Explore The Edit Tooltip Options :
# > ![image-2.png](attachment:image-2.png)
