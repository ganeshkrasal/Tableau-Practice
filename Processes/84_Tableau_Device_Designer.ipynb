# %% [markdown]
# # 84_Tableau_Device_Designer..,
# >>> ## *Tableau will help us to design layouts in Dashboard so that it properly visible in all the devices.., e.g. Mobile, Tab, Notebook etc..,*

# %% [markdown]
# > ### Step-I) Create Basic Charts :
# > ## 1) Sub-Category Sales : Bar Chart :
# > ![image.png](attachment:image.png)
# > ## 2) Sales-Trend (Order Piority) - Area Chart :
# > ![image-2.png](attachment:image-2.png)
# > ## 3) Order Priority wise Sales - Pie Chart :
# > ![image-3.png](attachment:image-3.png)
#
# > ### Step-II) Create Basic Dashboard & Observe : 2 Charts are not visible properly :
# > ![image-4.png](attachment:image-4.png)
#
# > ### Step-III) Change the Size to Automatic & Observe :
# > ![image-5.png](attachment:image-5.png)
#
# > ### Step-IV) Device Preview : Phone :
# > ![image-6.png](attachment:image-6.png)
# > ## AND
# > ![image-7.png](attachment:image-7.png)
#
# > ### Step-V) Device Preview : Tablet :
# > ![image-8.png](attachment:image-8.png)
