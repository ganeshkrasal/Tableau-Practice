# %% [markdown]
# # 63_Tableau_Funnel_Chart..,
# >> ### *Funnel Charts used to represent Sales at different sectors, stages, segments..,*
# >>> ### Top most part : Head..,
# >>> ### Bottom part : Neck..,

# %% [markdown]
# ## 1) Basic Funel Chart :
# > ### Step-I) Default Preview : Bar Chart with Colors : Segment Vs Sales :
# > ![image.png](attachment:image.png)
#
# > Step-II) DragDrop Sales to Size Mark :
# > ![image-2.png](attachment:image-2.png)
#
# > Step-III) The Entire View :
# > ![image-3.png](attachment:image-3.png)
#
# > Step-IV) The Funnel Chart : Output :
# > ![image-4.png](attachment:image-4.png)

# %% [markdown]
# ## 2) Advanced Funnel Chart :
# > ### Step-I) Create Area Chart :
# > ![image.png](attachment:image.png)
#
# > ### Step-II) Need to create NegativeSales Field :
# ![image-2.png](attachment:image-2.png)
#
# > ### Step-III) Plot NegativeSales to Create Funnel Shape :
# > ![image-3.png](attachment:image-3.png)
#
# > ### Step-IV) Observe Output :
# > ![image-4.png](attachment:image-4.png)
#
# > ### Step-V) The Advanced Funnel Chart :
# > ![image-5.png](attachment:image-5.png)
#
# > ## Advanced Funnel Chart :
# > ![image-6.png](attachment:image-6.png)
