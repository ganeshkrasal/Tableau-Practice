# %% [markdown]
# # 07_Tableau_DataTypes :

# %% [markdown]
# ### There are 6 Data Types :
# 1. Number (whole & decimal) - Numbers.,
# 1. Date & Time - Date along with time.,
# 1. Date - Date only,
# 1. String - Texts
# 1. Boolean - True or False.,
# 1. Geographic Role - City, Country, LatLong, Pin Code etc.,
#
# ![image.png](attachment:image.png)
