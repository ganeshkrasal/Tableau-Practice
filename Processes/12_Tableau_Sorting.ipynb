# %% [markdown]
# # 12_Tableau_Sorting..,

# %% [markdown]
# > ### Different types of SORTings : Quick Sort, Sorting by Toolbar, Sorting by Pills & Shortcut methods..?

# %% [markdown]
# ### QUICK Sort_01 :
#
# > ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ### QUICK Sort_02 :
# > ![image.png](attachment:image.png)

# %% [markdown]
# ### SORT From Toolbar_03 :
#
# > ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### SORT Form Pills_04 :
#
# > ![image-2.png](attachment:image-2.png)
#
# >> ![image-3.png](attachment:image-3.png)
#
# >> ![image-4.png](attachment:image-4.png)

# %% [markdown]
# ### Check for Labels Option :
#
# >> ![image.png](attachment:image.png)

# %% [markdown]
# ### Sort From Marks Card_05 :
#
# >> ![image.png](attachment:image.png)
