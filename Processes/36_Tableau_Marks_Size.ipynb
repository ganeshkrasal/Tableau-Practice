# %% [markdown]
# # 36_Tableau_Marks_Size..,
# >> ### How to change the Size of Graph, Chart, Map, Raw Data etc..,??

# %% [markdown]
# ## 1) Bar Graph :
# > ### Step-I) Graph Preview : Default view of Mark-Size :
# > ![image.png](attachment:image.png)
#
# > ### Step-II) Change Bar Size : Output
# > ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## 2) Line Chart :
# > ## Line Chart : Mark-Size Output :
# > ![image.png](attachment:image.png)

# %% [markdown]
# ## 3) Map :
# > ## Map : Mark-Size Output :
# > ![image.png](attachment:image.png)

# %% [markdown]
# ## 4) Raw Data :
# > ### Step-I) Create Raw :
# > ![image.png](attachment:image.png)
#
# > ### Step-II) Raw Data : Mark-Size Output :
# > ![image-2.png](attachment:image-2.png)
