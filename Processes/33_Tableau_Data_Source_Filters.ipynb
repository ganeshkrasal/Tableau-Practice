# %% [markdown]
# # 33_Tableau_Data_Source_Filters..,
# >> ### How to work with Data Source Filters..??
# >> ### *Data Source Filters means whatever Data we borrowed from other sources, that will be filtered.., And that Data Source Filters will be impacting other sheets also..,*

# %% [markdown]
# > ### Step-I) Graph Preview_01 :
# > ![image.png](attachment:image.png)
# > ### Step-II) Grapgh Preview_02 :
# > ![image-2.png](attachment:image-2.png)
# > ### Step-III) Graph Preview_03 :
# > ![image-3.png](attachment:image-3.png)
#
# > ## Step-IV) Creaet Filter : Part_01 :
# > ![image-4.png](attachment:image-4.png)
# > ## Step-IV) Create Filter : Part_02 :
# > ![image-5.png](attachment:image-5.png)
#
# > ## Step-V) Data Source Filter Ouput : Part_01 : Current Work Sheet
# > ![image-6.png](attachment:image-6.png)
# > ## Step-V) Data Source Filter Ouput : Part_01 : Other Work Sheet :
# > ## Explore the option to see the changes in other worksheets..,
