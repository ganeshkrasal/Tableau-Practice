# %% [markdown]
# # 54_Tableau_Introduction_Chart..,
# >> ### Tableau uses visualization query language for creating Charts..,

# %% [markdown]
# ## 1) Show Me :
# > ## Part_01 :
# > ![image.png](attachment:image.png)
# > ## Part_02 :
# > ![image-2.png](attachment:image-2.png)
#
# > ## Tableau Auto Suggest :
# > ![image-3.png](attachment:image-3.png)
#
# > ## Example_01)
# > ![image-5.png](attachment:image-5.png)
#
# > ## Example_02)
# > ![image-6.png](attachment:image-6.png)
#
# > ## Example_03)
# > ![image-7.png](attachment:image-7.png)

# %% [markdown]
# ## Shortcuts :
# > ## 1) 1st Double Click Measure AND 2nd Double Click Dimension :
# > ![image.png](attachment:image.png)
#
# > ## 2) 1st Double Click Dimension AND 2nd Double Click Measure :
# > ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## Explore Date Field Selection Option..,
