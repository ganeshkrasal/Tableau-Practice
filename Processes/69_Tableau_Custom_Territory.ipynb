# %% [markdown]
# # 69_Tableau_Custom_Territory..,
# >> ### Combining Areas : Group wise..,

# %% [markdown]
# ## 1) Create Custom Territory :
# > ### Step-I) Select & Group Members :
# > ![image.png](attachment:image.png)
#
# > ### Step-II) Groups Created :
# > ![image-2.png](attachment:image-2.png)
#
# > ### Step-III) Edit State(Group) :
# > ![image-3.png](attachment:image-3.png)
#
# > ### The Groups :
# > ![image-5.png](attachment:image-5.png)
#
# > ### Step-IV) Maps with Groups as Custom Territory Only :
# > ![image-6.png](attachment:image-6.png)

# %% [markdown]
# ## 2) New Territory with Calculations :
# > ![image.png](attachment:image.png)
