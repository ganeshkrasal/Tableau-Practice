# %% [markdown]
# # 24_Tableau_Managing_MetaData..,
# >> ### How to work with Managing MetaData..??
# >>> ### How do we Hide/Unhide the fields..??
# >>> ### How do we Rename different fields..??
# >>> ### How do we create different Hirearchies..??
# >>> ### How do we change different DataTypes..??
# >>> ### How to work with Calculating Fields..??

# %% [markdown]
# ## 1) Hide/Unhide :
# > ![image.png](attachment:image.png)

# %% [markdown]
# ## 2) Rename :
# > ![image.png](attachment:image.png)

# %% [markdown]
# ## 3) Hirearchy :
# ### e.g. Country - State - City.
# > ### a) Auto Hirearchy :
# > ![image.png](attachment:image.png)
#
# > ### b) Create Hirearchy :
# > ![image-2.png](attachment:image-2.png)
#
# > ### c) Hirearchy used :
# > ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ## 4) Folder :
# > ### Create Folder (2 Steps) :
# > ![image.png](attachment:image.png)
#
# > ### Folder Created :
# > ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## 5) Calculated Field :
#
# > ### a) Create Calculated Field :
# > ![image.png](attachment:image.png)
#
# > ### b) Calculated Field Usage :
# > ![image-2.png](attachment:image-2.png)
