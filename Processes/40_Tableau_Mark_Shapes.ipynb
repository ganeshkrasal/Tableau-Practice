# %% [markdown]
# # 40_Tableau_Mark_Shapes..,
# >> ### How to use Shapes in the Marks Card..??
# >> ### *Sometimes we don't want to use regular graphs, then shapes come into picture..,*

# %% [markdown]
# > ### Blank Window :
# > ![image-2.png](attachment:image-2.png)
#
# > ### Step-I) Shapes option :
# > ![image-4.png](attachment:image-4.png)
#
# > ### Step-II) Graph With Shapes :
# > ![image-5.png](attachment:image-5.png)
#
# > ## Add Customized Shapes.., Explore this option..,
# > ## C:\Users\Admin\Documents\My Tableau Repository\Shapes
