# %% [markdown]
# # 82_Tableau_Dashboard_Formatting..,

# %% [markdown]
# ## 1) Tiled Worksheets Option :
# > ## Select All the Worksheet in Tiled Option : (Auto arrange in worksheet)
# > ![image.png](attachment:image.png)
# ## 2) Floating Worksheets Option :
# > ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## 3) Add Filter & Apply it to All Worksheet Option Explore :
# > ### The Graph Windows are no changing their size..,
# > ![image.png](attachment:image.png)
#
# ## 4) Verticle Allignment :
# > ![image-2.png](attachment:image-2.png)
#
# ## 5) Horizontal Allignment :
# > ## Apply Filters & Observe :
# > ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ## 6) Edti Title Options :
# > ### Running Total by *'Category'*..,
# > ![image.png](attachment:image.png)
# > ## Observe the Output :
# > ![image-2.png](attachment:image-2.png)
