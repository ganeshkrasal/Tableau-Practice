# %% [markdown]
# # 81_Tabelau_Dashboard_Webpage..,

# %% [markdown]
# > ### Step-I) Default Preview : Dashboard
# > ![image.png](attachment:image.png)
#
# > ### Step-II) Dashboard-> Actions-> Add URL :
# > ![image-2.png](attachment:image-2.png)
# > ## Observe the Output :
# > ![image-3.png](attachment:image-3.png)
#
# > ### Step-III) URL Link Parameterization :
# > ![image-4.png](attachment:image-4.png)
# > ## Observe the Output :
# > ![image-5.png](attachment:image-5.png)
