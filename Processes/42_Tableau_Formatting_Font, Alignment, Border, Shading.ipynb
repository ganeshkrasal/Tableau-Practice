# %% [markdown]
# # 42_Tableau_Formatting_Font, Alignment, Border, Shading..,

# %% [markdown]
# ## 1) Font :
# > ### Step-I) Default Data View :
# > ![image.png](attachment:image.png)
#
# > ### Step-II) Format-> Font : Option :
# > ![image-3.png](attachment:image-3.png)
#
# > ### Step-III) Explore Various Font Options :
# > ![image-4.png](attachment:image-4.png)
#
# > ### Step-IV) Row & Column Grand Total Option :
# > ![image-5.png](attachment:image-5.png)
#
# > ### Step-V) Formatting Font with Row & Column Grand Totals : Output :
# > ![image-6.png](attachment:image-6.png)
#
# > ## Explore Font Option :
# > ![image-7.png](attachment:image-7.png)

# %% [markdown]
# ## 2) Alignment :
# > ### Explore Various Alignment Options Given :
# > ![image.png](attachment:image.png)

# %% [markdown]
# ## 3) Shading :
# > ## Explore Various Shading Options :
# > ![image.png](attachment:image.png)

# %% [markdown]
# ## 4) Shading :
# > ### Explore All the Options of Shading :
# > ![image.png](attachment:image.png)
