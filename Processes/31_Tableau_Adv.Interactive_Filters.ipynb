# %% [markdown]
# # 31_Tableau_Adv.Interactive_Filters.., (Dependent)
# >> ### How to work with Dependent Advanced Interactive Filters..??

# %% [markdown]
# ## 1) Dependent Filtes :
# > ### Graph Preview :
# ![image.png](attachment:image.png)
#
# > ### Step-I) Toggle Both the Filters :
# > ![image-2.png](attachment:image-2.png)
#
# > ### Step-II) Show 'Only Relevant Values' :
# > ![image-3.png](attachment:image-3.png)
#
# > ### Step-III) Output : 'Only Relevant Values' Option :
# > ![image-4.png](attachment:image-4.png)

# %% [markdown]
# ## 2) Date Interactive Filters :
# > ![image.png](attachment:image.png)
