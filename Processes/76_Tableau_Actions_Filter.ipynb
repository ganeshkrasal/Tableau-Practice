# %% [markdown]
# # 76_Tableau_Actions_Filter..,

# %% [markdown]
# > ### Step-I) Basic Preview :
# > ## Source Basic Preview :
# > ![image.png](attachment:image.png)
# > ## Target Basic Preview :
# > ![image-2.png](attachment:image-2.png)
#
# > ### Step-II) Explore The Opiotn : Filter Options Environment :
# > ![image-3.png](attachment:image-3.png)
#
# > ### Step-III) Selct On Source :
# > ![image-4.png](attachment:image-4.png)
# > ## Target Output (Auto Generated) :
# > ![image-5.png](attachment:image-5.png)
#
# > ## EXPLORE The Output Options :
# > ![image-6.png](attachment:image-6.png)
# > ## AND
# > ![image-7.png](attachment:image-7.png)
