# %% [markdown]
# # 10_Tableau_Sort :

# %% [markdown]
# > ### *How to Sort Columns, Records & Tables..??*

# %% [markdown]
# ### 1) Column Names Sorting :
#
# > ###  A-Z ascending/descending :
# >> *These options are used for sorting Column Names of Single Sheet/Table., i.e. Used when there is only one sheet..,*
#
# > ### A-Z ascending/descending per table :
# >> *These options are used for sorting Column Names of Multiple Sheets/Tables., i.e Used when there are multiple sheets..,*
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# > ### Fields/Records Sort :
#
# ![image.png](attachment:image.png)
