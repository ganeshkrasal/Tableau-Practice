# %% [markdown]
# # 61_Tableau_Tree_Maps..,

# %% [markdown]
# > ### 1) Simple Tree Map :
# > ![image.png](attachment:image.png)
#
# > ### 2) Color Tree Map : Dimension Selected for Color Mark :
# > ![image-2.png](attachment:image-2.png)
#
# > ### 3) Color Tree Map : Measure Selected for Color Mark :
# > ![image-3.png](attachment:image-3.png)
#
# > ### 4) Interactive Tree Maps :
# > ![image-4.png](attachment:image-4.png)
#
# > ## Explore the Options..,
