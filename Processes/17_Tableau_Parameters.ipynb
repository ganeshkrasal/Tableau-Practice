# %% [markdown]
# # 17_Tableau_Parameters..,

# %% [markdown]
# >> ### How to work with Parameters, Parameters with Filters & Parameters with sets..??
#
# *Parameters are the dynamic values which we can change & with which we can interact with our charts..,*

# %% [markdown]
# ### The Basic Grapgh :
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 1) Parameters With Filter :
# > ### a) Standard Way of Filtering :
# > ![image.png](attachment:image.png)
# > ### Output :
# > ![image-2.png](attachment:image-2.png)
#
# > ### b) Create Filter Parameter :
# > ![image-3.png](attachment:image-3.png)
# > ### Output :
# > ![image-4.png](attachment:image-4.png)

# %% [markdown]
# ## 2) Parameters with Sets :
# > ### Create Set :
# > ![image.png](attachment:image.png)
# > ### Output :
# > ![image-2.png](attachment:image-2.png)
# > ### Final Output of Parameters with Set :
# > ![image-3.png](attachment:image-3.png)
