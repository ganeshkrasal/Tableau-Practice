# %% [markdown]
# # 09_Tableau_Column_Formatting :

# %% [markdown]
# > ### *How to Copy, Rename, Split values into two different columns..??*

# %% [markdown]
# ### 1) Rename :
#
# - Double Click on column name & go ahead :
#
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### 2) Copy :
# - Same as that of MS Excel..,

# %% [markdown]
# ### 3) Split :
# ### A) Split :
# > Just right click on Column Name & select 'Split' - Column will automatically split in between as shown :
# ![image.png](attachment:image.png)

# %% [markdown]
# ### B) Custom Split :
# > Here we can choose the seperator in Custome Slit :
#
# ![image.png](attachment:image.png)
