# %% [markdown]
# # 71_Tableau_Region-Wise_Population..,

# %% [markdown]
# ## 1) The Dataset :
# > ![image.png](attachment:image.png)

# %% [markdown]
# ## 2) Do Map Settings :
# > ### *Adding Unknown Locations to the Map.., i.e. Geo Coding..,*

# %% [markdown]
# ## 3) The Map Output :
# > ![image.png](attachment:image.png)

# %% [markdown]
# ## 4) Edit Colors :
# > ### Change Color Pattern :
# > ![image.png](attachment:image.png)
#
# > ## Changed Color Output :
# > ![image-2.png](attachment:image-2.png)
