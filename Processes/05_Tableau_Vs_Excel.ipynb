# %% [markdown]
# # 05_Tableau_Vs_Excel..,

# %% [markdown]
# ## Excel :
# ### Step-I) : Check for Workbook Samples :
# > **Go to location** : *C:\Users\Admin\Documents\My Tableau Repository\Datasources\2021.2\en_US-US*

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Step-II) : Open Excel File :
# > **Work on Pivot Table** :

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Tableau :
# ### Step-I) : Connect to Excel Database :
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Step-II) : Open respective Sheet i.e. Orders :
# 1. Drag Tables :
# 2. Check For Sheets :
# 3. Open Sheet :
# 4. Drag Respective Dimension & Measure value to Rows & Columns :
#
# ![image.png](attachment:image.png)
