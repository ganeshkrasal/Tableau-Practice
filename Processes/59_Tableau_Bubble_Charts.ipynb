# %% [markdown]
# # 59_Tableau_Bubble_Charts..,
# >> ### *Circle represents Dimensions & Size represents Measures..,*

# %% [markdown]
# > ### 1) Bubble Chart_Sub Category : Output
# > ![image.png](attachment:image.png)
#
# > ### 2) Bubble Chart : Market :
# > ![image-2.png](attachment:image-2.png)
#
# > ### 3) Bubble Chart : Country (Too much data.,)
# > ![image-3.png](attachment:image-3.png)
