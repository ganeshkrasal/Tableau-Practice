# %% [markdown]
# # 29_Tableau_Date_Filters..,
# >> ### How to work with Date Filters..?? (Years, Months, Date, in Graphs)

# %% [markdown]
# > ### Graph Preview :
# > ![image.png](attachment:image.png)
#
# > ### Step-I) Apply Date Filters (Order Date) :
# > ![image-2.png](attachment:image-2.png)
#
# > ### Step-II) Explor Options : Relative Dates - Years, Quarters, Months & Weeks :
# > ![image-3.png](attachment:image-3.png)
#
# > ### Step-III) Range of Dates Option :
# > ![image-4.png](attachment:image-4.png)
#
# > ### Step-IV) Starting Date Option :
# > ![image-5.png](attachment:image-5.png)
#
# > ### Step-V) Ending Date Option :
# > ![image-6.png](attachment:image-6.png)
#
# > ### Step-VI) Special Date Option :
# > ![image-7.png](attachment:image-7.png)
