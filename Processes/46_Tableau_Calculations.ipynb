# %% [markdown]
# # 46_Tableau_Calculations..,
# >> ### How to work with Tableau Calculations..??

# %% [markdown]
# ## 1) Calculated Field :
# > ### Step-I) Default View Data :
# ![image.png](attachment:image.png)
#
# > ### Step-II) Create Calculated Field : (Cost = Sales - Profit)
# > ![image-2.png](attachment:image-2.png)
#
# > ### Step-III) Calculated Field Usage :
# > ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ## 2) Minimum & Maximum :
# > ### Step-I) Default View (Sum of Sales)
# > ![image.png](attachment:image.png)
#
# > ### Step-II) View Aggregate Measure Values :
# ![image-2.png](attachment:image-2.png)
#
# > ### Step-III) Aggregate Values :
# > ![image-3.png](attachment:image-3.png)
#
# > ### Step-IV) Create 'Minimum' & 'Maximum' Calculated Field :
# > ![image-4.png](attachment:image-4.png)
#
# > ### Step-V) Created Min-Max Fields :
# > ![image-5.png](attachment:image-5.png)
#
# > ## Showing Minimum & Maximum Values :
# > ![image-6.png](attachment:image-6.png)

# %% [markdown]
# ## 3) Ceiling & Floor :
# ## Floor :-
# > ### *The floor function is the function that takes as input a real number x, and gives as output the greatest integer less than or equal to x, denoted floor(x) or ⌊x⌋..,*
# ## Ceiling :-
# > ### *The ceiling function maps x to the least integer greater than or equal to x, denoted ceil(x) or ⌈x⌉.*
#
# > ### Step-I) Set Data For Ceiling & Floor :
# > ![image.png](attachment:image.png)
#
# > ### Step-II) Create 'Ceiling' & 'Floor' Calculated Field :
# > ![image-2.png](attachment:image-2.png)
#
# > ### Step-III) Ceiling & Floor Function Usage :
# > ![image-3.png](attachment:image-3.png)
