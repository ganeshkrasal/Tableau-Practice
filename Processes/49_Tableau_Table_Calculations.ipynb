# %% [markdown]
# # 49_Tableau_Table_Calculations..,
# >> ### There are two types of Calculations :
#
# >> ### 1. DataBase Calculations : *Related to database e.g. Difference, Min, Max, % etc.*
# >> ### 2. Table Calculations : *Calculations based on the output in Tableau..,*

# %% [markdown]
# ## 1) Percentage of Total : (%)
# > ### Step-I) Default Preview : Percentage of Total : Text Data :
# > ![image.png](attachment:image.png)
#
# > ### Step-II) Select Option : Percentage of Total :
# > ![image-2.png](attachment:image-2.png)
#
# > ### Step-III) Percentage of Total (Text Data) : Output
# > ![image-3.png](attachment:image-3.png)
#
# > ### Step-IV) Default Preview : Percentage of Total : Graph Data :
# > ![image-4.png](attachment:image-4.png)
#
# > ### Step-V) Select Option : Percentage of Total :
# > ![image-5.png](attachment:image-5.png)
#
# > ### Step-VI) Percentage of Total (Graph Data) : Output
# > ![image-6.png](attachment:image-6.png)

# %% [markdown]
# ## 2) Table Calculations :
# > ### Step-I) Default Preview : Line Graph :
# > ![image-2.png](attachment:image-2.png)
#
# > ### Step-II) Convert Line to Bar Graph :
# > ![image-3.png](attachment:image-3.png)
# > ### Graphs with Text Labels :
# > ![image-5.png](attachment:image-5.png)
#
# > ### Step-III) Select Percentage of Total Option for one of the Bar Values :
# > ![image-6.png](attachment:image-6.png)
#
# > ### Step-IV) Output (Explore the Options) :
# > ![image-7.png](attachment:image-7.png)

# %% [markdown]
# ## 3) Table Calculations : Cross Tab :
# > ### Explore the option :
# > ### ![image.png](attachment:image.png)

# %% [markdown]
# ## 4) How to Differentiate :
# > ### Step-I) Default Preview :
# > ![image.png](attachment:image.png)
#
# > ### Step-II) Prepare for Running Total (Cumulative Total) :
# > ![image-2.png](attachment:image-2.png)
# > ### Converted Data looks a like ;
# ![image-3.png](attachment:image-3.png)
#
# > ### Step-III) Select Running Total option :
# > ![image-4.png](attachment:image-4.png)
#
# > ### Step-IV) Running Total : Output :
# > ![image-5.png](attachment:image-5.png)
#
# > ## Explore the options :
# ![image-6.png](attachment:image-6.png)

# %% [markdown]
# ## 5) Running Total : Bar Graph :
# > ### Step-I) Create Default View:
# > ![image.png](attachment:image.png)
#
# > ### Step-II) Running Total : Bar Graph : Output :
# > ![image-2.png](attachment:image-2.png)
#
# > ### Running Total : Explore the Option : See the Output Curve :
# ![image-3.png](attachment:image-3.png)
