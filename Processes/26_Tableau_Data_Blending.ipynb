# %% [markdown]
# # 26_Tableau_Data_Blending..,
# >> ### How to work with Data Blending in Tableau..??

# %% [markdown]
# ## Joins Vs Data Blending
# > ### Joins :
# >> *We combine data from multiple data sources & represents in the form of graphs..*
# > ### Blending :
# >> *Same things will do by using Blending but with more advanced features which Joind doesn't support..*

# %% [markdown]
# ## The Datasets :
# > ### Step-I) Data_Blending_Office City Sales AND Data_Blending_Coffee Chain Sales :
# > ![image.png](attachment:image.png)
#
# > ### Step-II) Dataset Views :
# > ![image-2.png](attachment:image-2.png)
#
# ## The Aim to see Grapgh of Sales Vs Region in both the files, so for Territory - EDIT Relationships :
# > ### Step-III) Define Relationship between Region & Territory :
# > ![image-3.png](attachment:image-3.png)
# >> ### Created Relation Ship :
# >> ![image-4.png](attachment:image-4.png)
#
# > ### Step-IV) 'Coffee Sales Vs State' Graph (Primary Data Source - Coffee Chain Sales) :
# > ![image-5.png](attachment:image-5.png)
#
# > ### Step-V) 'Office Sales Vs State' Graph (Primary Data Source - Office City Sales) :
# > ![image-6.png](attachment:image-6.png)
#
# > ### Step-VI) Graph with both ethe Datasets : Primary & Secondary (Explore Washington Option)
# > ![image-7.png](attachment:image-7.png)
#
# > ### Step-VII) Graph with both ethe Datasets : Primary & Secondary (When everything is OK) :
# > ![image-8.png](attachment:image-8.png)
