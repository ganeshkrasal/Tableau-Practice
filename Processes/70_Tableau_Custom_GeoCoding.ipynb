# %% [markdown]
# # 70_Tableau_Custom_GeoCoding..,
# >> ### *We can customize Geographical Area which is not recognized by Tableau..,*

# %% [markdown]
# ## 1) Edit Locations :
# > ### Step-I) Edit Locations for Unknown :
# > ![image-2.png](attachment:image-2.png)
#
# > ### Step-II) Edit Locations : Explore The Option :
# > ![image-3.png](attachment:image-3.png)
#
# > ## Explore the Option :
# > ![image-4.png](attachment:image-4.png)
