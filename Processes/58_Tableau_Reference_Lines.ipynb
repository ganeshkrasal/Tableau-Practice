# %% [markdown]
# # 58_Tableau_Reference_Lines..,
# >> ### *Reference Lines make work easy, where we can compare values Less Than or Greater Than..,*

# %% [markdown]
# ## 1) Releference Line : (Sales above or below average)
# > ### Step-I) Create Default Preview :
# > ![image.png](attachment:image.png)
#
# > ### Step-II) Create Reference Line : Explore Options :
# > ![image-2.png](attachment:image-2.png)
#
# > ### Step-III) Reference Line : Entire Table : Output :
# > ![image-3.png](attachment:image-3.png)
#
# > ### Step-IV) Reference Line : Per Pane : Output : (Average/Category)
# > ![image-4.png](attachment:image-4.png)

# %% [markdown]
# ## 2) Reference Band :
# > ### Step-I) Create Reference Band :
# > ![image.png](attachment:image.png)
#
# > ### Step-II) Reference Band Output : Average to Maximum :
# > ![image-2.png](attachment:image-2.png)
#
# > ### Step-III) Reference Band Output : Minimum to Average :
# > ![image-3.png](attachment:image-3.png)
#
# > ### Explore Various Outputs :
# ![image-4.png](attachment:image-4.png)

# %% [markdown]
# ## 3) Reference Distribution :
# > ### Step-I) Create Reference Distribution :
# > ![image.png](attachment:image.png)
#
# > ### Step-II) Reference Distribution : Output :
# > ![image-2.png](attachment:image-2.png)
#
# > ### Explore Various Outputs :
# > ![image-3.png](attachment:image-3.png)
# > ## AND
# > ![image-4.png](attachment:image-4.png)
