# %% [markdown]
# # 48_Tableau_String_Functions..,
# >> ### How to work with String Related Functions..??

# %% [markdown]
# ## 1) Upper & Lower Text :
# > ### Step-I) Create Calculated Fields : UpperText & LowerText :
# > ![image.png](attachment:image.png)
#
# > ### Step-II) Calculated Fields : UpperText & LowerText Usage :
# > ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## 2) LeftMost & RightMost :
# > ### Step-I) Create Calculated Fields : LeftMost & RightMost :
# > ![image.png](attachment:image.png)
#
# > ### Step-II) Calculated Field LEFT & RIGHT Usage :
# > ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## 3) Split : (Splits Text into different parts..,)
# > ### Step-I) Custom Split : Split-off - First :
# > ![image.png](attachment:image.png)
#
# > ### Step-II) Custom Split : Split-off : First Output :
# > ![image-2.png](attachment:image-2.png)
#
# > ### Step-III) Custom Split : Split-off - Last :
# > ![image-3.png](attachment:image-3.png)
#
# > ### Step-IV) Custom Split : Split-off : Last Output :
# > ![image-4.png](attachment:image-4.png)
#
# > ### Step-V) Single Click Split : AutoSplit :
# > ![image-5.png](attachment:image-5.png)
#
# > ### Step-VI) Single Click Split : AutoSplit Output :
# > ![image-6.png](attachment:image-6.png)
