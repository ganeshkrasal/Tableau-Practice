# %% [markdown]
# # 30_Tableau_Interactive Filters..,
# >> ### Dashboard Interaction increaes from this topic :

# %% [markdown]
# ## 1) Introducion : Graph Preview :
# > ![image.png](attachment:image.png)
#
# > ### Step-I) Create Filter :
# > ![image-2.png](attachment:image-2.png)
#
# > ### Step-II) Another Way of Show Filter :
# > ![image-4.png](attachment:image-4.png)

# %% [markdown]
# ## 2) Interactive Filters : Layouts :
# > ### Step-I) Single Value List :
# > ![image.png](attachment:image.png)
#
# > ### Step-II) Single Value DropDown :
# > ![image-2.png](attachment:image-2.png)
#
# > ### Step-III) Single Value Slider :
# > ![image-3.png](attachment:image-3.png)
#
# > ### Step-IV) Multiple Values List :
# > ![image-4.png](attachment:image-4.png)
#
# > ### Step-V) Multiple Values Dropdown :
# > ![image-5.png](attachment:image-5.png)
#
# > ### Step-VI) Multiple Values Custom List :
# > ![image-6.png](attachment:image-6.png)
