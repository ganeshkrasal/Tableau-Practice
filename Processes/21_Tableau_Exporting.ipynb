# %% [markdown]
# # 21_Tableau_Exporting..,
# >> ### What are the different methods by which we can export Tableau Data into different places..??
#
# > ### Excel, Powerpoint, MS Database Acccess, TWBX (Tableau Packaged Workbook) stc..,

# %% [markdown]
# ## 1) Save as TWBX (Tableau Packaged Workbook)
# > ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## 2) Print to PDF :
# > ### Check for Print Option & Explore :

# %% [markdown]
# ## 3) Export to Image, Data & Excel Formats :
# > ![image.png](attachment:image.png)
