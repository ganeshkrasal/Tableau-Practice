# %% [markdown]
# # 78_Tableau_Actions_URL..,
# >>> ### Actions triggers based on URL (Web Portal)..,

# %% [markdown]
# ## 1) Worksheet URL Action :
# > ### Step-I) Create Default Preview :
# > ![image.png](attachment:image.png)
# > ## AND
# > ![image-2.png](attachment:image-2.png)
#
# > ### Step-II) Create 'Go to URL' Action :
# > ![image-3.png](attachment:image-3.png)
#
# > ### Step-III) Select any State to see URL action :
# > ![image-4.png](attachment:image-4.png)
# > ## AND You will directed towars the link in URL Action Tab :
# > ![image-5.png](attachment:image-5.png)
# > ## Select any state and you will be directed towards the same link..,
#
# > ### Step-IV) Parameterize the 'Go to URL' Action :
# > ![image-6.png](attachment:image-6.png)
#
# > ### Step-V) Repeat the Output Step : Selec any State & see URL Action :
# > ![image-7.png](attachment:image-7.png)
# > ## AND You will directed towars the Parameterized link in URL Action Tab :
# > ![image-8.png](attachment:image-8.png)
#
# > ## EXPLORE Various output Options :
# > ![image-9.png](attachment:image-9.png)

# %% [markdown]
# ## 2) Dashboard URL Action :
# > ### Step-I) Create Dashbard Action & EXPLORE The Output :
# > ![image.png](attachment:image.png)

# %% [markdown]
# ## 3) Dashboard Webpage Option :
# > ### Create Dashboard Webpage :
# > ![image.png](attachment:image.png)
#
# > ## EXPLORE The Output Options :
# > ![image-2.png](attachment:image-2.png)
