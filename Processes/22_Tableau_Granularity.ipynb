# %% [markdown]
# # 22_Tableau_Granularity..,

# %% [markdown]
# >> ## Granularity in simple terms means breaking down into small pieces..,

# %% [markdown]
# ## Granularity :
# > ### Step-I) Only on point :
# > ![image.png](attachment:image.png)
#
# > ### Step-II) Added Category to the Color Mark : (3 points added)
# > ![image-3.png](attachment:image-3.png)
#
# > ### Step-III) Added Ship Mode to Size Mark :
# > ![image-4.png](attachment:image-4.png)
#
# > ### Step-IV) Added City to Color Mark :
# > ![image-5.png](attachment:image-5.png)
