# %% [markdown]
# # 83_Tableau_Story_Point..,
# >>> ### Story Point is a sequential way of Visualizng analyzed data..,

# %% [markdown]
# > ## Create Different Graphs :
# > ## 1) Funnel Chart :
# > ![image.png](attachment:image.png)
# > ## 2) Area Chart :
# > ![image-2.png](attachment:image-2.png)
# > ## 3) Bar Chart :
# > ![image-3.png](attachment:image-3.png)
# > ## 4) Map :
# > ![image-4.png](attachment:image-4.png)
# > ## 5) Word :
# > ![image-5.png](attachment:image-5.png)

# %% [markdown]
# > ### Step-I) Create Story Interface :
# > ![image.png](attachment:image.png)
#
# > ### Step-II) DRAGDROP 1st Worksheet to Story :
# > ![image-2.png](attachment:image-2.png)
#
# > ### Step-III) Add Next Worksheet :
# > ![image-3.png](attachment:image-3.png)
#
# > ### Step-IV) Add remaining worksheets with Caption :
# > ![image-4.png](attachment:image-4.png)
#
# > ## The Tableau Story : Expolre the Options :
# > ![image-5.png](attachment:image-5.png)
