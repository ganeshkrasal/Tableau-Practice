# %% [markdown]
# # 34_Tableau_Ways_To_Filter..,
# >> ### What are the different ways by which we can filter our Data..??

# %% [markdown]
# ## 1) By Filter Shelf :
# > ### Step-I) Graph Preview :
# > ![image-3.png](attachment:image-3.png)
#
# > ### Step-II) Create Filter from Filter Shelf :
# > ![image-4.png](attachment:image-4.png)
#
# > ### Step-III) Filter Shelf Output :
# > ![image-5.png](attachment:image-5.png)

# %% [markdown]
# ## 2) Interactive Filter :
# > ### Step-I) Graph Preview :
# > ![image.png](attachment:image.png)
#
# > ### Step-II) Create Filter :
# > ![image-2.png](attachment:image-2.png)
#
# > ### Step-III) Interactive Filter Output :
# > ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ## 3) Headers :
# > ### Step-I) Graph Preview :
# > ![image.png](attachment:image.png)
#
# > ### Step-II) Header Filter : Double Click on Individual Filed :
# > ![image-2.png](attachment:image-2.png)
#
# > ### Step-III) Header Filter : Keep Only Option :
# > ![image-3.png](attachment:image-3.png)
# > ### Step-IV) Header Filter Output :
# > ![image-4.png](attachment:image-4.png)

# %% [markdown]
# ## 4) Legends :
# > ### Step-I) Graph Preview :
# > ![image.png](attachment:image.png)
#
# > ### Step-II) Create Legends Filter :
# > ![image-2.png](attachment:image-2.png)
#
# > ### Steo-III) Legend Filter Output :
# > ![image-3.png](attachment:image-3.png)
