# %% [markdown]
# # 37_Tableau_Mark-Color..,
# >> ##

# %% [markdown]
# ## 1) Bar Graph :
# > ### Bar Graph : Mark-Color Category Output :
# > ![image.png](attachment:image.png)
#
# > ### Bar Graph : Mark-Color Market Output :
# > ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## 2) Map :
# > ### Map : Mark-Color Profit Output :
# > ![image.png](attachment:image.png)

# %% [markdown]
# ## 3) Line Chart :
# > ### Line Chart : Mark-Color Region Output :
# > ![image.png](attachment:image.png)

# %% [markdown]
# ## 4) Raw Data :
# > ### Raw Data : Mark-Color Region Output :
# > ![image.png](attachment:image.png)
