# %% [markdown]
# # 18_Tableau_Combine..,

# %% [markdown]
# >> ### How to work with Combine..??
#
# *Combine is basically used to combine 2 or more dimensions togather.., For better data analysis..,*

# %% [markdown]
# ## 1) Highest Sales :
# > ### In Normal Way :
# > ![image.png](attachment:image.png)

# %% [markdown]
# ## 2) Highest Sales with Combine :
# > ### Create Combined Field:
# > ![image.png](attachment:image.png)
# > ### Output :
# > ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## 3) Highest Sales TWO :
# > ### This method is having limits :
# > ![image.png](attachment:image.png)

# %% [markdown]
# ## 4) Highest Sales with Combine_TWO :
# > ![image.png](attachment:image.png)
#
# > ### The Output :
# > ![image-2.png](attachment:image-2.png)
