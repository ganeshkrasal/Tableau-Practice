# %% [markdown]
# # 35_Tableau_Format_Filters..,
# >> ### How to format Filters, those are like interactive Filters..??

# %% [markdown]
# ## Format Filter :
# > ### Step-I) Graph Preview :
# > ![image.png](attachment:image.png)
#
# > ### Step-II) Explore Format Filter Option :
# > ![image-2.png](attachment:image-2.png)
#
# > ### Step-III) Format Filter : Worksheet Output :
# > ![image-3.png](attachment:image-3.png)
#
# > ### Step-IV) Create New Dashboard (1st Time) :
# > ![image-4.png](attachment:image-4.png)
#
# > ### Step-V) Format Filter : Dashboard Output :
# > ![image-5.png](attachment:image-5.png)
#
# > ### Step-VI) Edit Title Option in Workdheet :
# > ![image-6.png](attachment:image-6.png)
# > ### Reflected Edit Title in Dashboard :
# > ![image-7.png](attachment:image-7.png)
#
# > ### Step-VII) Format Filter : Show Apply Button :
# > ![image-8.png](attachment:image-8.png)
