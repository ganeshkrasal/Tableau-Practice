# %% [markdown]
# # 80_Tableau_Dashboard_Introduction..,
# >>> ### Dashboards are the colleciton of different views, all the different worksheets at one place..,

# %% [markdown]
# > ### Step-I) Create Different Worksheets :
# > ![image.png](attachment:image.png)
# > ![image-3.png](attachment:image-3.png)
# > ## AND
# > ![image-2.png](attachment:image-2.png)
#
# > ### Step-II) Dashboard Preview :
# > ![image-4.png](attachment:image-4.png)
#
# > ### Step-III) Create Dashboard :
# > ![image-5.png](attachment:image-5.png)
#
# > ### Step-IV) Apply Filters to a Single Worksheet :
# > ![image-6.png](attachment:image-6.png)
# > ## Output :
# > ![image-7.png](attachment:image-7.png)
#
# > ### Step-V) Apply Filters Changes to Every Sheet : EXPLORE Option :
# > ![image-8.png](attachment:image-8.png)
# > ## Output :
# > ![image-9.png](attachment:image-9.png)
