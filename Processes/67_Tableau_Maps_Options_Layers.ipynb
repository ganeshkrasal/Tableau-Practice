# %% [markdown]
# # 67_Tableau_Maps_Options_Layers..,

# %% [markdown]
# ## 1) The Map Options :
# > ![image.png](attachment:image.png)
# ## AND
# > ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## Map Layers : Explore the Option..,
