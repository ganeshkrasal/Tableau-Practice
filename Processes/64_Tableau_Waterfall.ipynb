# %% [markdown]
# # 64_Tableau_Waterfall..,

# %% [markdown]
# > ### Step-I) Default Preview : Bar Chart
# > ![image.png](attachment:image.png)
#
# > Step-II) Convert Bar Chart to Gantt Chart :
# > ![image-2.png](attachment:image-2.png)
#
# > ## Gantt Chart Output :
# > ![image-3.png](attachment:image-3.png)
#
# > ### Step-IV) Give Sales Size & Color to Gantt Chart & Convert it to Waterfall Chart :
# > ![image-4.png](attachment:image-4.png)
#
# > ## The WaterFall Chart :
# > ![image-5.png](attachment:image-5.png)

# %% [markdown]
# ## Profit Wataerfall :
# > ![image.png](attachment:image.png)
# > ![image-2.png](attachment:image-2.png)
